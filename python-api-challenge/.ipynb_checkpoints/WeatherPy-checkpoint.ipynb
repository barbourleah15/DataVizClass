# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Resources used:
# openweathermap.org
# https://www.geeksforgeeks.org/python-find-current-weather-of-any-city-using-openweathermap-api/
# 
#

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import csv

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 623

# %%
# To show the cities being pulled in - for my own use.
print(cities)
# Out:
# ['cabo san lucas', 'hermanus', 'japura', 'narsaq', 'fare', 'new norfolk', 'flin flon', 'atuona', 'viedma', 'bluff', 'torbay', 'buctzotz', 'upernavik', 'rikitea', 'belushya guba', 'taolanaro', 'salalah', 'port hardy', 'port pirie', 'illoqqortoormiut', 'chagda', 'san agustin', 'ushuaia', 'dikson', 'sadon', 'tasiilaq', 'sao joao da barra', 'albany', 'talnakh', 'broome', 'ishigaki', 'esperance', 'timmins', 'tiznit', 'aykhal', 'jamestown', 'barrow', 'hilo', 'ribeira grande', 'amderma', 'puerto leguizamo', 'punta arenas', 'port elizabeth', 'coihueco', 'poya', 'brae', 'arraial do cabo', 'cidreira', 'kruisfontein', 'mataura', 'chuy', 'portland', 'qui nhon', 'taltal', 'orcopampa', 'petropavlovsk-kamchatskiy', 'faanui', 'lebu', 'qaanaaq', 'mecca', 'abu samrah', 'nyurba', 'guerrero negro', 'merritt island', 'leningradskiy', 'tiksi', 'port lincoln', 'longyearbyen', 'bellevue', 'college', 'cape town', 'panaba', 'havelock', 'busselton', 'bredasdorp', 'belyy yar', 'eldorado', 'rawson', 'traralgon', 'east london', 'barentsburg', 'katsuura', 'gayny', 'muborak', 'pevek', 'ilulissat', 'los llanos de aridane', 'vaitupu', 'abnub', 'meulaboh', 'chokurdakh', 'carnarvon', 'hwange', 'sentyabrskiy', 'fallon', 'rio gallegos', 'praia da vitoria', 'palmerston', 'san patricio', 'berlevag', 'nikolskoye', 'luganville', 'kodiak', 'hobart', 'kapaa', 'oistins', 'bethel', 'lagunas', 'artyk', 'dolbeau', 'saint-philippe', 'ambikapur', 'liverpool', 'itoman', 'yellowknife', 'talas', 'darhan', 'prince george', 'saskylakh', 'ewa beach', 'lagoa', 'masvingo', 'codrington', 'ponta do sol', 'saleaula', 'port alfred', 'khatanga', 'salinopolis', 'la ronge', 'antofagasta', 'high level', 'balikpapan', 'lolua', 'algiers', 'ulladulla', 'mar del plata', 'touros', 'mangrol', 'samusu', 'areia branca', 'grand river south east', 'dicabisagan', 'las cruces', 'butaritari', 'tura', 'sao filipe', 'yumen', 'dingzhou', 'sakaraha', 'cherskiy', 'kargopol', 'tuktoyaktuk', 'tignere', 'arica', 'hasaki', 'aligudarz', 'avarua', 'rosario do sul', 'akyab', 'kabare', 'waitati', 'roma', 'hithadhoo', 'castro', 'sartell', 'severo-kurilsk', 'yeppoon', 'hirara', 'mahebourg', 'victoria', 'mouila', 'san cristobal', 'babati', 'yakima', 'erzurum', 'lompoc', 'mujiayingzi', 'hambantota', 'roebourne', 'dunedin', 'wahran', 'grand-lahou', 'puerto escondido', 'vaini', 'idrinskoye', 'kingaroy', 'wattegama', 'sobolevo', 'aklavik', 'malanje', 'kahului', 'puerto ayora', 'eura', 'nhulunbuy', 'korla', 'helong', 'we', 'constitucion', 'tambul', 'qaqortoq', 'nelson bay', 'bonavista', 'mapiripan', 'tuatapere', 'michigan city', 'thessalon', 'maningrida', 'comodoro rivadavia', 'nizhneyansk', 'ati', 'mehamn', 'mabaruma', 'ugoofaaru', 'fairbanks', 'alta floresta', 'zhuhai', 'uglich', 'twentynine palms', 'tidore', 'makakilo city', 'portsmouth', 'soverato', 'airai', 'tubruq', 'tahe', 'libertador general san martin', 'nalut', 'thompson', 'ostrovnoy', 'tateyama', 'provideniya', 'lavrentiya', 'haibowan', 'lagoa vermelha', 'rach gia', 'huarmey', 'maxixe', 'sorvag', 'coihaique', 'labuhan', 'yamada', 'hofn', 'kuche', 'attawapiskat', 'fortuna', 'nakasongola', 'fukue', 'natal', 'marystown', 'komsomolskiy', 'ancud', 'otradnoye', 'mount gambier', 'ausa', 'daru', 'yar-sale', 'saldanha', 'oranjemund', 'tabuk', 'kavaratti', 'cockburn town', 'clyde river', 'chernyshevskiy', 'sande', 'georgetown', 'darnah', 'srandakan', 'det udom', 'gauribidanur', 'chumikan', 'ponta delgada', 'corrales', 'maniitsoq', 'yerbogachen', 'aktash', 'mannarakkat', 'samba', 'dingle', 'teguise', 'banff', 'buala', 'urumqi', 'saint george', 'marcona', 'ardistan', 'the valley', 'uvarovo', 'miraflores', 'lincoln', 'muisne', 'goias', 'geraldton', 'marabba', 'norman wells', 'bilibino', 'jalu', 'bambous virieux', 'rabaul', 'boca do acre', 'lorengau', 'tanakpur', 'lazaro cardenas', 'komarichi', 'khed brahma', 'palabuhanratu', 'aitape', 'wanning', 'sorland', 'shitkino', 'sharlyk', 'waynesville', 'saint-francois', 'marienburg', 'olafsvik', 'nicoya', 'antalaha', 'port blair', 'man ...

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# To call in and print the response to have the set-up of the data - for my own use.
url = "http://api.openweathermap.org/data/2.5/weather?"

query_url = url + "appid=" + api_key + "&q=" + city

cloudiness_response = requests.get(query_url).json()

cloudiness_response
# Out:
# {'coord': {'lon': 21.26, 'lat': -28.45},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03n'}],
#  'base': 'stations',
#  'main': {'temp': 290.15,
#   'feels_like': 290.21,
#   'temp_min': 290.15,
#   'temp_max': 290.15,
#   'pressure': 1017,
#   'humidity': 93},
#  'wind': {'speed': 2.67, 'deg': 315},
#  'clouds': {'all': 31},
#  'dt': 1583117252,
#  'sys': {'type': 1,
#   'id': 1990,
#   'country': 'ZA',
#   'sunrise': 1583123282,
#   'sunset': 1583168784},
#  'timezone': 7200,
#  'id': 945945,
#  'name': 'Upington',
#  'cod': 200}

# %%
# From geeksforgeeks.org to verify the data being pulled in matches my expectations of a known city -for my own use.

url = "http://api.openweathermap.org/data/2.5/weather?"
town = "cabo san lucas"

query_url = url + "appid=" + api_key + "&q=" + town

response = requests.get(query_url) 
x = response.json() 
  
# Now x contains list of nested dictionaries 
# Check the value of "cod" key is equal to 
# "404", means city is found otherwise, 
# city is not found 
if x["cod"] != "404": 
  
    # store the value of "main" 
    # key in variable y 
    y = x["main"] 
  
    # store the value corresponding 
    # to the "temp" key of y 
    current_temperature = y["temp"] 
  
    # store the value corresponding 
    # to the "pressure" key of y 
    current_pressure = y["pressure"] 
  
    # store the value corresponding 
    # to the "humidity" key of y 
    current_humidiy = y["humidity"] 
  
    # store the value of "weather" 
    # key in variable z 
    z = x["weather"] 
  
    # store the value corresponding  
    # to the "description" key at  
    # the 0th index of z 
    weather_description = z[0]["description"] 
  
    # print following values 
    print(" Temperature (in kelvin unit) = " +
                    str(current_temperature) + 
          "\n atmospheric pressure (in hPa unit) = " +
                    str(current_pressure) +
          "\n humidity (in percentage) = " +
                    str(current_humidiy) +
          "\n description = " +
                    str(weather_description)) 
  
else: 
    print(" City Not Found ")
# Out:
#  Temperature (in kelvin unit) = 276.15
#  atmospheric pressure (in hPa unit) = 992
#  humidity (in percentage) = 74
#  description = overcast clouds

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
query_url = url + "appid=" + api_key + "&q="

cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []
city_name = []

print("Beginning Data Retrival \n-----------------------------")

for x in range(len(cities)):
    try:
        print(f"Processing record {x} of Set 1 | {cities[x]}")

        city_logs = requests.get(query_url + cities[x]).json
    
    except:
        print("City not found... Skipping.")
        
        city_logs
# Out:
# Beginning Data Retrival
# -----------------------------
# Processing record 0 of Set 1 | cabo san lucas
# Processing record 1 of Set 1 | hermanus
# Processing record 2 of Set 1 | japura
# Processing record 3 of Set 1 | narsaq
# Processing record 4 of Set 1 | fare
# Processing record 5 of Set 1 | new norfolk
# Processing record 6 of Set 1 | flin flon
# Processing record 7 of Set 1 | atuona
# Processing record 8 of Set 1 | viedma
# Processing record 9 of Set 1 | bluff
# Processing record 10 of Set 1 | torbay
# Processing record 11 of Set 1 | buctzotz
# Processing record 12 of Set 1 | upernavik
# Processing record 13 of Set 1 | rikitea
# Processing record 14 of Set 1 | belushya guba
# Processing record 15 of Set 1 | taolanaro
# Processing record 16 of Set 1 | salalah
# Processing record 17 of Set 1 | port hardy
# Processing record 18 of Set 1 | port pirie
# Processing record 19 of Set 1 | illoqqortoormiut
# Processing record 20 of Set 1 | chagda
# Processing record 21 of Set 1 | san agustin
# Processing record 22 of Set 1 | ushuaia
# Processing record 23 of Set 1 | dikson
# Processing record 24 of Set 1 | sadon
# Processing record 25 of Set 1 | tasiilaq
# Processing record 26 of Set 1 | sao joao da barra
# Processing record 27 of Set 1 | albany
# Processing record 28 of Set 1 | talnakh
# Processing record 29 of Set 1 | broome
# Processing record 30 of Set 1 | ishigaki
# Processing record 31 of Set 1 | esperance
# Processing record 32 of Set 1 | timmins
# Processing record 33 of Set 1 | tiznit
# Processing record 34 of Set 1 | aykhal
# Processing record 35 of Set 1 | jamestown
# Processing record 36 of Set 1 | barrow
# Processing record 37 of Set 1 | hilo
# Processing record 38 of Set 1 | ribeira grande
# Processing record 39 of Set 1 | amderma
# Processing record 40 of Set 1 | puerto leguizamo
# Processing record 41 of Set 1 | punta arenas
# Processing record 42 of Set 1 | port elizabeth
# Processing record 43 of Set 1 | coihueco
# Processing record 44 of Set 1 | poya
# Processing record 45 of Set 1 | brae
# Processing record 46 of Set 1 | arraial do cabo
# Processing record 47 of Set 1 | cidreira
# Processing record 48 of Set 1 | kruisfontein
# Processing record 49 of Set 1 | mataura
# Processing record 50 of Set 1 | chuy
# Processing record 51 of Set 1 | portland
# Processing record 52 of Set 1 | qui nhon
# Processing record 53 of Set 1 | taltal
# Processing record 54 of Set 1 | orcopampa
# Processing record 55 of Set 1 | petropavlovsk-kamchatskiy
# Processing record 56 of Set 1 | faanui
# Processing record 57 of Set 1 | lebu
# Processing record 58 of Set 1 | qaanaaq
# Processing record 59 of Set 1 | mecca
# Processing record 60 of Set 1 | abu samrah
# Processing record 61 of Set 1 | nyurba
# Processing record 62 of Set 1 | guerrero negro
# Processing record 63 of Set 1 | merritt island
# Processing record 64 of Set 1 | leningradskiy
# Processing record 65 of Set 1 | tiksi
# Processing record 66 of Set 1 | port lincoln
# Processing record 67 of Set 1 | longyearbyen
# Processing record 68 of Set 1 | bellevue
# Processing record 69 of Set 1 | college
# Processing record 70 of Set 1 | cape town
# Processing record 71 of Set 1 | panaba
# Processing record 72 of Set 1 | havelock
# Processing record 73 of Set 1 | busselton
# Processing record 74 of Set 1 | bredasdorp
# Processing record 75 of Set 1 | belyy yar
# Processing record 76 of Set 1 | eldorado
# Processing record 77 of Set 1 | rawson
# Processing record 78 of Set 1 | traralgon
# Processing record 79 of Set 1 | east london
# Processing record 80 of Set 1 | barentsburg
# Processing record 81 of Set 1 | katsuura
# Processing record 82 of Set 1 | gayny
# Processing record 83 of Set 1 | muborak
# Processing record 84 of Set 1 | pevek
# Processing record 85 of Set 1 | ilulissat
# Processing record 86 of Set 1 | los llanos de aridane
# Processing record 87 of Set 1 | vaitupu
# Processing record 88 of Set 1 | abnub
# Processing record 89 of Set 1 | meulaboh
# Processing record 90 of Set 1 | chokurdakh
# Processing record 91 of Set 1 | carnarvon
# Processing record 92 of Set 1 | hwange
# Processing record 93 of Set 1 | sentyabrskiy
# Processing record 94 of Set 1 | fallon
# Processing record 95 of Set 1 | rio gallegos
# Processing record 96 of Set 1 | praia da vitoria
# Processing record 97 of Set 1 | palmerston
# Processing record 98 of Set 1 | san patricio
# Processing record 99 of Set 1 | berlevag
# Processing record 100 of Set 1 | nikolskoye
# Processing record 101 of Set 1 | luganville
# Processing record 102 of Set 1 | kodiak
# Processing record 103 of Set 1 | hobart
# Processing record 104 of Set 1 | kapaa
# Processing record 105 of Set 1 | oistins
# Processing record 106 of Set 1 | bethel
# Processing record 107 of Set 1 | lagunas
# Processing record 108 of Set 1 | artyk
# Processing record 109 of Set 1 | dolbeau
# Processing record 110 of Set 1 | saint-philippe
# Processing record 111 of Set 1 | ambikapur
# Processing record 112 of Set 1 | liverpool
# Processing record 113 of Set 1 | itoman
# Processing record 114 of Set 1 | yellowknife
# Processing record 115 of Set 1 | talas
# Processing record 116 of Set 1 | darhan
# Processing record 117 of Set 1 | prince george
# Processing record 118 of Set 1 | saskylakh
# Processing record 119 of Set 1 | ewa beach
# Processing record 120 of Set 1 | lagoa
# Processing record 121 of Set 1 | masvingo
# Processing record 122 of Set 1 | codrington
# Processing record 123 of Set 1 | ponta do sol
# Processing record 124 of Set 1 | saleaula
# Processing record 125 of Set 1 | port alfred
# Processing record 126 of Set 1 | khatanga
# Processing record 127 of Set 1 | salinopolis
# Processing record 128 of Set 1 | la ronge
# Processing record 129 of Set 1 | antofagasta
# Processing record 130 of Set 1 | high level
# Processing record 131 of Set 1 | balikpapan
# Processing record 132 of Set 1 | lolua
# Processing record 133 of Set 1 | algiers
# Processing record 134 of Set 1 | ulladulla
# Processing record 135 of Set 1 | mar del plata
# Processing record 136 of Set 1 | touros
# Processing record 137 of Set 1 | mangrol
# Processing record 138 of Set 1 | samusu
# Processing record 139 of Set 1 | areia branca
# Processing record 140 of Set 1 | grand river south east
# Processing record 141 of Set 1 | dicabisagan
# Processing record 142 of Set 1 | las cruces
# Processing record 143 of Set 1 | butaritari
# Processing record 144 of Set 1 | tura
# Processing record 145 of Set 1 | sao filipe
# Processing record 146 of Set 1 | yumen
# Processing record 147 of Set 1 | dingzhou
# Processing record 148 of Set 1 | sakaraha
# Processing record 149 of Set 1 | cherskiy
# Processing record 150 of Set 1 | kargopol
# Processing record 151 of Set 1 | tuktoyaktuk
# Processing record 152 of Set 1 | tignere
# Processing record 153 of Set 1 | arica
# Processing record 154 of Set 1 | hasaki
# Processing record 155 of Set 1 | aligudarz
# Processing record 156 of Set 1 | avarua
# Processing record 157 of Set 1 | rosario do sul
# Processing record 158 of Set 1 | akyab
# Processing record 159 of Set 1 | kabare
# Processing record 160 of Set 1 | waitati
# Processing record 161 of Set 1 | roma
# Processing record 162 of Set 1 | hithadhoo
# Processing record 163 of Set 1 | castro
# Processing record 164 of Set 1 | sartell
# Processing record 165 of Set 1 | severo-kurilsk
# Processing record 166 of Set 1 | yeppoon
# Processing record 167 of Set 1 | hirara
# Processing record 168 of Set 1 | mahebourg
# Processing record 169 of Set 1 | victoria
# Processing record 170 of Set 1 | mouila
# Processing record 171 of Set 1 | san cristobal
# Processing record 172 of Set 1 | babati
# Processing record 173 of Set 1 | yakima
# Processing record 174 of Set 1 | erzurum
# Processing record 175 of Set 1 | lompoc
# Processing record 176 of Set 1 | mujiayingzi
# Processing record 177 of Set 1 | hambantota
# Processing record 178 of Set 1 | roebourne
# Processing record 179 of Set 1 | dunedin
# Processing record 180 of Set 1 | wahran
# Processing record 181 of Set 1 | grand-lahou
# Processing record 182 of Set 1 | puerto escondido
# Processing record 183 of Set 1 | vaini
# Processing record 184 of Set 1 | idrinskoye
# Processing record 185 of Set 1 | kingaroy
# Processing record 186 of Set 1 | wattegama
# Processing record 187 of Set 1 | sobolevo
# Processing record 188 of Set 1 | aklavik
# Processing record 189 of Set 1 | malanje
# Processing record 190 of Set 1 | kahului
# Processing record 191 of Set 1 | puerto ayora
# Processing record 192 of Set 1 | eura
# Processing record 193 of Set 1 | nhulunbuy
# Processing record 194 of Set 1 | korla
# Processing record 195 of Set 1 | helong
# Processing record 196 of Set 1 | we
# Processing record 197 of Set 1 | constitucion
# Processing record 198 of Set 1 | tambul
# Processing record 199 of Set 1 | qaqortoq
# Processing record 200 of Set 1 | nelson bay
# Processing record 201 of Set 1 | bonavista
# Processing record 202 of Set 1 | mapiripan
# Processing record 203 of Set 1 | tuatapere
# Processing record 204 of Set 1 | michigan city
# Processing record 205 of Set 1 | thessalon
# Processing record 206 of Set 1 | maningrida
# Processing record 207 of Set 1 | comodoro rivadavia
# Processing record 208 of Set 1 | nizhneyansk
# Processing record 209 of Set 1 | ati
# Processing record 210 of Set 1 | mehamn
# Processing record 211 of Set 1 | mabaruma
# Processing record 212 of Set 1 | ugoofaaru
# Processing record 213 of Set 1 | fairbanks
# Processing record 214 of Set 1 | alta floresta
# Processing record 215 of Set 1 | zhuhai
# Processing record 216 of Set 1 | uglich
# Processing record 217 of Set 1 | twentynine palms
# Processing record 218 of Set 1 | tidore
# Processing record 219 of Set 1 | makakilo city
# Processing record 220 of Set 1 | portsmouth
# Processing record 221 of Set 1 | soverato
# Processing record 222 of Set 1 | airai
# Processing record 223 of Set 1 | tubruq
# Processing record 224 of Set 1 | tahe
# Processing record 225 of Set 1 | libertador general san martin
# Processing record 226 of Set 1 | nalut
# Processing record 227 of Set 1 | thompson
# Processing record 228 of Set 1 | ostrovnoy
# Processing record 229 of Set 1 | tateyama
# Processing record 230 of Set 1 | provideniya
# Processing record 231 of Set 1 | lavrentiya
# Processing record 232 of Set 1 | haibowan
# Processing record 233 of Set 1 | lagoa vermelha
# Processing record 234 of Set 1 | rach gia
# Processing record 235 of Set 1 | huarmey
# Processing record 236 of Set 1 | maxixe
# Processing record 237 of Set 1 | sorvag
# Processing record 238 of Set 1 | coihaique
# Processing record 239 of Set 1 | labuhan
# Processing record 240 of Set 1 | yamada
# Processing record 241 of Set 1 | hofn
# Processing record 242 of Set 1 | kuche
# Processing record 243 of Set 1 | attawapiskat
# Processing record 244 of Set 1 | fortuna
# Processing record 245 of Set 1 | nakasongola
# Processing record 246 of Set 1 | fukue
# Processing record 247 of Set 1 | natal
# Processing record 248 of Set 1 | marystown
# Processing record 249 of Set 1 | komsomolskiy
# Processing record 250 of Set 1 | ancud
# Processing record 251 of Set 1 | otradnoye
# Processing record 252 of Set 1 | mount gambier
# Processing record 253 of Set 1 | ausa
# Processing record 254 of Set 1 | daru
# Processing record 255 of Set 1 | yar-sale
# Processing record 256 of Set 1 | saldanha
# Processing record 257 of Set 1 | oranjemund
# Processing record 258 of Set 1 | tabuk
# Processing record 259 of Set 1 | kavaratti
# Processing record 260 of Set 1 | cockburn town
# Processing record 261 of Set 1 | clyde river
# Processing record 262 of Set 1 | chernyshevskiy
# Processing record 263 of Set 1 | sande
# Processing record 264 of Set 1 | georgetown
# Processing record 265 of Set 1 | darnah
# Processing record 266 of Set 1 | srandakan
# Processing record 267 of Set 1 | det udom
# Processing record 268 of Set 1 | gauribidanur
# Processing record 269 of Set 1 | chumikan
# Processing record 270 of Set 1 | ponta delgada
# Processing record 271 of Set 1 | corrales
# Processing record 272 of Set 1 | maniitsoq
# Processing record 273 of Set 1 | yerbogachen
# Processing record 274 of Set 1 | aktash
# Processing record 275 of Set 1 | mannarakkat
# Processing record 276 of Set 1 | samba
# Processing record 277 of Set 1 | dingle
# Processing record 278 of Set 1 | teguise
# Processing record 279 of Set 1 | banff
# Processing record 280 of Set 1 | buala
# Processing record 281 of Set 1 | urumqi
# Processing record 282 of Set 1 | saint george
# Processing record 283 of Set 1 | marcona
# Processing record 284 of Set 1 | ardistan
# Processing record 285 of Set 1 | the valley
# Processing record 286 of Set 1 | uvarovo
# Processing record 287 of Set 1 | miraflores
# Processing record 288 of Set 1 | lincoln
# Processing record 289 of Set 1 | muisne
# Processing record 290 of Set 1 | goias
# Processing record 291 of Set 1 | geraldton
# Processing record 292 of Set 1 | marabba
# Processing record 293 of Set 1 | norman wells
# Processing record 294 of Set 1 | bilibino
# Processing record 295 of Set 1 | jalu
# Processing record 296 of Set 1 | bambous virieux
# Processing record 297 of Set 1 | rabaul
# Processing record 298 of Set 1 | boca do acre
# Processing record 299 of Set 1 | lorengau
# Processing record 300 of Set 1 | tanakpur
# Processing record 301 of Set 1 | lazaro cardenas
# Processing record 302 of Set 1 | komarichi
# Processing record 303 of Set 1 | khed brahma
# Processing record 304 of Set 1 | palabuhanratu
# Processing record 305 of Set 1 | aitape
# Processing record 306 of Set 1 | wanning
# Processing record 307 of Set 1 | sorland
# Processing record 308 of Set 1 | shitkino
# Processing record 309 of Set 1 | sharlyk
# Processing record 310 of Set 1 | waynesville
# Processing record 311 of Set 1 | saint-francois
# Processing record 312 of Set 1 | marienburg
# Processing record 313 of Set 1 | olafsvik
# Processing record 314 of Set 1 | nicoya
# Processing record 315 of Set 1 | antalaha
# Processing record 316 of Set 1 | port blair
# Processing record 317 of Set 1 | manama
# Processing record 318 of Set 1 | ambilobe
# Processing record 319 of Set 1 | mumford
# Processing record 320 of Set 1 | madang
# Processing record 321 of Set 1 | jarjis
# Processing record 322 of Set 1 | quelimane
# Processing record 323 of Set 1 | namibe
# Processing record 324 of Set 1 | kampene
# Processing record 325 of Set 1 | shimoda
# Processing record 326 of Set 1 | hovd
# Processing record 327 of Set 1 | kieta
# Processing record 328 of Set 1 | sladkovo
# Processing record 329 of Set 1 | mezen
# Processing record 330 of Set 1 | galiwinku
# Processing record 331 of Set 1 | bukachacha
# Processing record 332 of Set 1 | bengkulu
# Processing record 333 of Set 1 | klaksvik
# Processing record 334 of Set 1 | semey
# Processing record 335 of Set 1 | sabang
# Processing record 336 of Set 1 | mana
# Processing record 337 of Set 1 | cuencame
# Processing record 338 of Set 1 | vila franca do campo
# Processing record 339 of Set 1 | kenai
# Processing record 340 of Set 1 | nandu
# Processing record 341 of Set 1 | banjar
# Processing record 342 of Set 1 | pallasovka
# Processing record 343 of Set 1 | pisco
# Processing record 344 of Set 1 | kamaishi
# Processing record 345 of Set 1 | buraydah
# Processing record 346 of Set 1 | shush
# Processing record 347 of Set 1 | zhezkazgan
# Processing record 348 of Set 1 | wukari
# Processing record 349 of Set 1 | atbasar
# Processing record 350 of Set 1 | mahenge
# Processing record 351 of Set 1 | aswan
# Processing record 352 of Set 1 | guymon
# Processing record 353 of Set 1 | sinazongwe
# Processing record 354 of Set 1 | storsteinnes
# Processing record 355 of Set 1 | grindavik
# Processing record 356 of Set 1 | conde
# Processing record 357 of Set 1 | megion
# Processing record 358 of Set 1 | tsihombe
# Processing record 359 of Set 1 | santa isabel do rio negro
# Processing record 360 of Set 1 | kamenskoye
# Processing record 361 of Set 1 | omboue
# Processing record 362 of Set 1 | mata
# Processing record 363 of Set 1 | homer
# Processing record 364 of Set 1 | sakakah
# Processing record 365 of Set 1 | matadi
# Processing record 366 of Set 1 | presidente medici
# Processing record 367 of Set 1 | bose
# Processing record 368 of Set 1 | matara
# Processing record 369 of Set 1 | sao miguel do araguaia
# Processing record 370 of Set 1 | muros
# Processing record 371 of Set 1 | gat
# Processing record 372 of Set 1 | grand gaube
# Processing record 373 of Set 1 | kollumerland
# Processing record 374 of Set 1 | khani
# Processing record 375 of Set 1 | shiyan
# Processing record 376 of Set 1 | cairns
# Processing record 377 of Set 1 | miri
# Processing record 378 of Set 1 | srednekolymsk
# Processing record 379 of Set 1 | emba
# Processing record 380 of Set 1 | lucapa
# Processing record 381 of Set 1 | tezu
# Processing record 382 of Set 1 | vestmannaeyjar
# Processing record 383 of Set 1 | vrangel
# Processing record 384 of Set 1 | bonga
# Processing record 385 of Set 1 | half moon bay
# Processing record 386 of Set 1 | saint anthony
# Processing record 387 of Set 1 | nome
# Processing record 388 of Set 1 | turayf
# Processing record 389 of Set 1 | betioky
# Processing record 390 of Set 1 | burns lake
# Processing record 391 of Set 1 | vila velha
# Processing record 392 of Set 1 | talmenka
# Processing record 393 of Set 1 | jaora
# Processing record 394 of Set 1 | sorrento
# Processing record 395 of Set 1 | elwood
# Processing record 396 of Set 1 | pizarro
# Processing record 397 of Set 1 | aulla
# Processing record 398 of Set 1 | ambovombe
# Processing record 399 of Set 1 | menongue
# Processing record 400 of Set 1 | sur
# Processing record 401 of Set 1 | puerto lempira
# Processing record 402 of Set 1 | paamiut
# Processing record 403 of Set 1 | alofi
# Processing record 404 of Set 1 | camacha
# Processing record 405 of Set 1 | harihar
# Processing record 406 of Set 1 | moerai
# Processing record 407 of Set 1 | nanortalik
# Processing record 408 of Set 1 | mission
# Processing record 409 of Set 1 | viisoara
# Processing record 410 of Set 1 | saint marys
# Processing record 411 of Set 1 | bilma
# Processing record 412 of Set 1 | floresta
# Processing record 413 of Set 1 | milos
# Processing record 414 of Set 1 | sikonge
# Processing record 415 of Set 1 | gurgan
# Processing record 416 of Set 1 | safaga
# Processing record 417 of Set 1 | wuda
# Processing record 418 of Set 1 | bubaque
# Processing record 419 of Set 1 | myski
# Processing record 420 of Set 1 | bermeo
# Processing record 421 of Set 1 | nagorsk
# Processing record 422 of Set 1 | banda aceh
# Processing record 423 of Set 1 | morgan city
# Processing record 424 of Set 1 | himatnagar
# Processing record 425 of Set 1 | swift current
# Processing record 426 of Set 1 | gazojak
# Processing record 427 of Set 1 | skjervoy
# Processing record 428 of Set 1 | matay
# Processing record 429 of Set 1 | norheimsund
# Processing record 430 of Set 1 | north bay
# Processing record 431 of Set 1 | ballina
# Processing record 432 of Set 1 | walvis bay
# Processing record 433 of Set 1 | mitsamiouli
# Processing record 434 of Set 1 | guilin
# Processing record 435 of Set 1 | amahai
# Processing record 436 of Set 1 | soure
# Processing record 437 of Set 1 | inirida
# Processing record 438 of Set 1 | haines junction
# Processing record 439 of Set 1 | arroio grande
# Processing record 440 of Set 1 | havre-saint-pierre
# Processing record 441 of Set 1 | irbeyskoye
# Processing record 442 of Set 1 | dehloran
# Processing record 443 of Set 1 | nyazepetrovsk
# Processing record 444 of Set 1 | naze
# Processing record 445 of Set 1 | goure
# Processing record 446 of Set 1 | pauini
# Processing record 447 of Set 1 | tual
# Processing record 448 of Set 1 | fuerte olimpo
# Processing record 449 of Set 1 | bolpur
# Processing record 450 of Set 1 | avera
# Processing record 451 of Set 1 | kavieng
# Processing record 452 of Set 1 | bethlehem
# Processing record 453 of Set 1 | la palma
# Processing record 454 of Set 1 | toora-khem
# Processing record 455 of Set 1 | nambucca heads
# Processing record 456 of Set 1 | beihai
# Processing record 457 of Set 1 | ossora
# Processing record 458 of Set 1 | ixtapa
# Processing record 459 of Set 1 | ketchikan
# Processing record 460 of Set 1 | matamoros
# Processing record 461 of Set 1 | ngukurr
# Processing record 462 of Set 1 | rungata
# Processing record 463 of Set 1 | nishihara
# Processing record 464 of Set 1 | muyezerskiy
# Processing record 465 of Set 1 | palmas
# Processing record 466 of Set 1 | pahrump
# Processing record 467 of Set 1 | mount isa
# Processing record 468 of Set 1 | la romana
# Processing record 469 of Set 1 | tarudant
# Processing record 470 of Set 1 | marzuq
# Processing record 471 of Set 1 | chicama
# Processing record 472 of Set 1 | maromitsa
# Processing record 473 of Set 1 | zhangjiakou
# Processing record 474 of Set 1 | pochutla
# Processing record 475 of Set 1 | louis trichardt
# Processing record 476 of Set 1 | olavarria
# Processing record 477 of Set 1 | osmanabad
# Processing record 478 of Set 1 | krasnovishersk
# Processing record 479 of Set 1 | tilichiki
# Processing record 480 of Set 1 | marfino
# Processing record 481 of Set 1 | barroualie
# Processing record 482 of Set 1 | mishan
# Processing record 483 of Set 1 | bambanglipuro
# Processing record 484 of Set 1 | high prairie
# Processing record 485 of Set 1 | longavi
# Processing record 486 of Set 1 | sakaiminato
# Processing record 487 of Set 1 | tautira
# Processing record 488 of Set 1 | brezova pod bradlom
# Processing record 489 of Set 1 | farmington
# Processing record 490 of Set 1 | aranos
# Processing record 491 of Set 1 | candido mendes
# Processing record 492 of Set 1 | qasigiannguit
# Processing record 493 of Set 1 | egvekinot
# Processing record 494 of Set 1 | anori
# Processing record 495 of Set 1 | yantal
# Processing record 496 of Set 1 | mafinga
# Processing record 497 of Set 1 | rawlins
# Processing record 498 of Set 1 | port hedland
# Processing record 499 of Set 1 | bargal
# Processing record 500 of Set 1 | dalbandin
# Processing record 501 of Set 1 | ampanihy
# Processing record 502 of Set 1 | henties bay
# Processing record 503 of Set 1 | padang
# Processing record 504 of Set 1 | yichang
# Processing record 505 of Set 1 | kalispell
# Processing record 506 of Set 1 | pilar
# Processing record 507 of Set 1 | hami
# Processing record 508 of Set 1 | hamilton
# Processing record 509 of Set 1 | nioro
# Processing record 510 of Set 1 | sitka
# Processing record 511 of Set 1 | shache
# Processing record 512 of Set 1 | saquarema
# Processing record 513 of Set 1 | manzhouli
# Processing record 514 of Set 1 | cayenne
# Processing record 515 of Set 1 | virginia beach
# Processing record 516 of Set 1 | maldonado
# Processing record 517 of Set 1 | luderitz
# Processing record 518 of Set 1 | zhoucun
# Processing record 519 of Set 1 | mogadishu
# Processing record 520 of Set 1 | caravelas
# Processing record 521 of Set 1 | aasiaat
# Processing record 522 of Set 1 | denpasar
# Processing record 523 of Set 1 | porosozero
# Processing record 524 of Set 1 | quatre cocos
# Processing record 525 of Set 1 | te anau
# Processing record 526 of Set 1 | alice springs
# Processing record 527 of Set 1 | kamyshla
# Processing record 528 of Set 1 | faya
# Processing record 529 of Set 1 | chama
# Processing record 530 of Set 1 | san borja
# Processing record 531 of Set 1 | namatanai
# Processing record 532 of Set 1 | humaita
# Processing record 533 of Set 1 | saumur
# Processing record 534 of Set 1 | yongan
# Processing record 535 of Set 1 | mlonggo
# Processing record 536 of Set 1 | bairiki
# Processing record 537 of Set 1 | lasa
# Processing record 538 of Set 1 | thinadhoo
# Processing record 539 of Set 1 | kysyl-syr
# Processing record 540 of Set 1 | jingdezhen
# Processing record 541 of Set 1 | pangnirtung
# Processing record 542 of Set 1 | turbat
# Processing record 543 of Set 1 | soyo
# Processing record 544 of Set 1 | mandalgovi
# Processing record 545 of Set 1 | noumea
# Processing record 546 of Set 1 | louisbourg
# Processing record 547 of Set 1 | xining
# Processing record 548 of Set 1 | taoudenni
# Processing record 549 of Set 1 | lubao
# Processing record 550 of Set 1 | leh
# Processing record 551 of Set 1 | dawei
# Processing record 552 of Set 1 | kalmunai
# Processing record 553 of Set 1 | bodaybo
# Processing record 554 of Set 1 | tonantins
# Processing record 555 of Set 1 | pacific grove
# Processing record 556 of Set 1 | waingapu
# Processing record 557 of Set 1 | saryshagan
# Processing record 558 of Set 1 | zhigansk
# Processing record 559 of Set 1 | forssa
# Processing record 560 of Set 1 | tumannyy
# Processing record 561 of Set 1 | chapais
# Processing record 562 of Set 1 | vao
# Processing record 563 of Set 1 | praya
# Processing record 564 of Set 1 | bhadrachalam
# Processing record 565 of Set 1 | honningsvag
# Processing record 566 of Set 1 | terrace
# Processing record 567 of Set 1 | palmer
# Processing record 568 of Set 1 | port arthur
# Processing record 569 of Set 1 | general roca
# Processing record 570 of Set 1 | roswell
# Processing record 571 of Set 1 | bathsheba
# Processing record 572 of Set 1 | coquimbo
# Processing record 573 of Set 1 | ordzhonikidze
# Processing record 574 of Set 1 | timra
# Processing record 575 of Set 1 | hobyo
# Processing record 576 of Set 1 | mbanza-ngungu
# Processing record 577 of Set 1 | llanes
# Processing record 578 of Set 1 | gwadar
# Processing record 579 of Set 1 | byron bay
# Processing record 580 of Set 1 | yanan
# Processing record 581 of Set 1 | russell
# Processing record 582 of Set 1 | port macquarie
# Processing record 583 of Set 1 | shingu
# Processing record 584 of Set 1 | hadsten
# Processing record 585 of Set 1 | talara
# Processing record 586 of Set 1 | santa cruz
# Processing record 587 of Set 1 | lieksa
# Processing record 588 of Set 1 | hazorasp
# Processing record 589 of Set 1 | eyl
# Processing record 590 of Set 1 | pemba
# Processing record 591 of Set 1 | raudeberg
# Processing record 592 of Set 1 | souillac
# Processing record 593 of Set 1 | hvolsvollur
# Processing record 594 of Set 1 | mandera
# Processing record 595 of Set 1 | lundazi
# Processing record 596 of Set 1 | celestun
# Processing record 597 of Set 1 | kolda
# Processing record 598 of Set 1 | golfito
# Processing record 599 of Set 1 | ust-nera
# Processing record 600 of Set 1 | ozernovskiy
# Processing record 601 of Set 1 | corbelia
# Processing record 602 of Set 1 | kaitangata
# Processing record 603 of Set 1 | luena
# Processing record 604 of Set 1 | nortelandia
# Processing record 605 of Set 1 | oberwil
# Processing record 606 of Set 1 | necochea
# Processing record 607 of Set 1 | sinnamary
# Processing record 608 of Set 1 | goderich
# Processing record 609 of Set 1 | rehnan
# Processing record 610 of Set 1 | evensk
# Processing record 611 of Set 1 | afgoye
# Processing record 612 of Set 1 | jiwani
# Processing record 613 of Set 1 | germersheim
# Processing record 614 of Set 1 | ust-barguzin
# Processing record 615 of Set 1 | vardo
# Processing record 616 of Set 1 | salvador
# Processing record 617 of Set 1 | isangel
# Processing record 618 of Set 1 | iquique
# Processing record 619 of Set 1 | mount darwin
# Processing record 620 of Set 1 | verkhnyaya inta
# Processing record 621 of Set 1 | ler
# Processing record 622 of Set 1 | upington

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"

cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []
city_name = []

print("Beginning Data Retrival \n-----------------------------")

for x in range(len(cities)):
    try:     
        print(f"Processing Record {x + 1} | {cities[x]}")
        query_url = url + "appid=" + api_key + "&q=" + cities[x]
        weather_response = requests.get(query_url).json()
        cloudiness.append(weather_response["clouds"]["all"])
        country.append(weather_response["sys"]["country"])
        date.append(weather_response["dt"])
        humidity.append(weather_response["main"]["humidity"])
        lat.append(weather_response["coord"]["lat"])
        lng.append(weather_response["coord"]["lon"])
        max_temp.append(weather_response["main"]["temp_max"])
        wind_speed.append(weather_response["wind"]["speed"])
        city_name.append(weather_response["name"])
    except:
        print("City not found. Skipping...")
# Out:
# Beginning Data Retrival
# -----------------------------
# Processing Record 1 | cabo san lucas
# Processing Record 2 | hermanus
# Processing Record 3 | japura
# Processing Record 4 | narsaq
# Processing Record 5 | fare
# Processing Record 6 | new norfolk
# Processing Record 7 | flin flon
# Processing Record 8 | atuona
# Processing Record 9 | viedma
# Processing Record 10 | bluff
# Processing Record 11 | torbay
# Processing Record 12 | buctzotz
# Processing Record 13 | upernavik
# Processing Record 14 | rikitea
# Processing Record 15 | belushya guba
# City not found. Skipping...
# Processing Record 16 | taolanaro
# City not found. Skipping...
# Processing Record 17 | salalah
# Processing Record 18 | port hardy
# Processing Record 19 | port pirie
# Processing Record 20 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 | chagda
# City not found. Skipping...
# Processing Record 22 | san agustin
# Processing Record 23 | ushuaia
# Processing Record 24 | dikson
# Processing Record 25 | sadon
# Processing Record 26 | tasiilaq
# Processing Record 27 | sao joao da barra
# Processing Record 28 | albany
# Processing Record 29 | talnakh
# Processing Record 30 | broome
# Processing Record 31 | ishigaki
# Processing Record 32 | esperance
# Processing Record 33 | timmins
# Processing Record 34 | tiznit
# Processing Record 35 | aykhal
# Processing Record 36 | jamestown
# Processing Record 37 | barrow
# Processing Record 38 | hilo
# Processing Record 39 | ribeira grande
# Processing Record 40 | amderma
# City not found. Skipping...
# Processing Record 41 | puerto leguizamo
# Processing Record 42 | punta arenas
# Processing Record 43 | port elizabeth
# Processing Record 44 | coihueco
# Processing Record 45 | poya
# Processing Record 46 | brae
# Processing Record 47 | arraial do cabo
# Processing Record 48 | cidreira
# Processing Record 49 | kruisfontein
# Processing Record 50 | mataura
# Processing Record 51 | chuy
# Processing Record 52 | portland
# Processing Record 53 | qui nhon
# Processing Record 54 | taltal
# Processing Record 55 | orcopampa
# Processing Record 56 | petropavlovsk-kamchatskiy
# Processing Record 57 | faanui
# Processing Record 58 | lebu
# Processing Record 59 | qaanaaq
# Processing Record 60 | mecca
# Processing Record 61 | abu samrah
# Processing Record 62 | nyurba
# Processing Record 63 | guerrero negro
# Processing Record 64 | merritt island
# Processing Record 65 | leningradskiy
# Processing Record 66 | tiksi
# Processing Record 67 | port lincoln
# Processing Record 68 | longyearbyen
# Processing Record 69 | bellevue
# Processing Record 70 | college
# Processing Record 71 | cape town
# Processing Record 72 | panaba
# Processing Record 73 | havelock
# Processing Record 74 | busselton
# Processing Record 75 | bredasdorp
# Processing Record 76 | belyy yar
# Processing Record 77 | eldorado
# Processing Record 78 | rawson
# Processing Record 79 | traralgon
# Processing Record 80 | east london
# Processing Record 81 | barentsburg
# City not found. Skipping...
# Processing Record 82 | katsuura
# Processing Record 83 | gayny
# Processing Record 84 | muborak
# Processing Record 85 | pevek
# Processing Record 86 | ilulissat
# Processing Record 87 | los llanos de aridane
# Processing Record 88 | vaitupu
# City not found. Skipping...
# Processing Record 89 | abnub
# Processing Record 90 | meulaboh
# Processing Record 91 | chokurdakh
# Processing Record 92 | carnarvon
# Processing Record 93 | hwange
# Processing Record 94 | sentyabrskiy
# City not found. Skipping...
# Processing Record 95 | fallon
# Processing Record 96 | rio gallegos
# Processing Record 97 | praia da vitoria
# Processing Record 98 | palmerston
# Processing Record 99 | san patricio
# Processing Record 100 | berlevag
# Processing Record 101 | nikolskoye
# Processing Record 102 | luganville
# Processing Record 103 | kodiak
# Processing Record 104 | hobart
# Processing Record 105 | kapaa
# Processing Record 106 | oistins
# Processing Record 107 | bethel
# Processing Record 108 | lagunas
# Processing Record 109 | artyk
# City not found. Skipping...
# Processing Record 110 | dolbeau
# City not found. Skipping...
# Processing Record 111 | saint-philippe
# Processing Record 112 | ambikapur
# Processing Record 113 | liverpool
# Processing Record 114 | itoman
# Processing Record 115 | yellowknife
# Processing Record 116 | talas
# Processing Record 117 | darhan
# Processing Record 118 | prince george
# Processing Record 119 | saskylakh
# Processing Record 120 | ewa beach
# Processing Record 121 | lagoa
# Processing Record 122 | masvingo
# Processing Record 123 | codrington
# Processing Record 124 | ponta do sol
# Processing Record 125 | saleaula
# City not found. Skipping...
# Processing Record 126 | port alfred
# Processing Record 127 | khatanga
# Processing Record 128 | salinopolis
# Processing Record 129 | la ronge
# Processing Record 130 | antofagasta
# Processing Record 131 | high level
# Processing Record 132 | balikpapan
# Processing Record 133 | lolua
# City not found. Skipping...
# Processing Record 134 | algiers
# Processing Record 135 | ulladulla
# Processing Record 136 | mar del plata
# Processing Record 137 | touros
# Processing Record 138 | mangrol
# Processing Record 139 | samusu
# City not found. Skipping...
# Processing Record 140 | areia branca
# Processing Record 141 | grand river south east
# City not found. Skipping...
# Processing Record 142 | dicabisagan
# Processing Record 143 | las cruces
# Processing Record 144 | butaritari
# Processing Record 145 | tura
# Processing Record 146 | sao filipe
# Processing Record 147 | yumen
# Processing Record 148 | dingzhou
# Processing Record 149 | sakaraha
# Processing Record 150 | cherskiy
# Processing Record 151 | kargopol
# Processing Record 152 | tuktoyaktuk
# Processing Record 153 | tignere
# Processing Record 154 | arica
# Processing Record 155 | hasaki
# Processing Record 156 | aligudarz
# Processing Record 157 | avarua
# Processing Record 158 | rosario do sul
# Processing Record 159 | akyab
# Processing Record 160 | kabare
# Processing Record 161 | waitati
# Processing Record 162 | roma
# Processing Record 163 | hithadhoo
# Processing Record 164 | castro
# Processing Record 165 | sartell
# Processing Record 166 | severo-kurilsk
# Processing Record 167 | yeppoon
# Processing Record 168 | hirara
# Processing Record 169 | mahebourg
# Processing Record 170 | victoria
# Processing Record 171 | mouila
# Processing Record 172 | san cristobal
# Processing Record 173 | babati
# Processing Record 174 | yakima
# Processing Record 175 | erzurum
# Processing Record 176 | lompoc
# Processing Record 177 | mujiayingzi
# Processing Record 178 | hambantota
# Processing Record 179 | roebourne
# Processing Record 180 | dunedin
# Processing Record 181 | wahran
# City not found. Skipping...
# Processing Record 182 | grand-lahou
# Processing Record 183 | puerto escondido
# Processing Record 184 | vaini
# Processing Record 185 | idrinskoye
# Processing Record 186 | kingaroy
# Processing Record 187 | wattegama
# Processing Record 188 | sobolevo
# Processing Record 189 | aklavik
# Processing Record 190 | malanje
# Processing Record 191 | kahului
# Processing Record 192 | puerto ayora
# Processing Record 193 | eura
# Processing Record 194 | nhulunbuy
# Processing Record 195 | korla
# Processing Record 196 | helong
# Processing Record 197 | we
# City not found. Skipping...
# Processing Record 198 | constitucion
# Processing Record 199 | tambul
# City not found. Skipping...
# Processing Record 200 | qaqortoq
# Processing Record 201 | nelson bay
# Processing Record 202 | bonavista
# Processing Record 203 | mapiripan
# Processing Record 204 | tuatapere
# Processing Record 205 | michigan city
# Processing Record 206 | thessalon
# Processing Record 207 | maningrida
# Processing Record 208 | comodoro rivadavia
# Processing Record 209 | nizhneyansk
# City not found. Skipping...
# Processing Record 210 | ati
# Processing Record 211 | mehamn
# Processing Record 212 | mabaruma
# Processing Record 213 | ugoofaaru
# Processing Record 214 | fairbanks
# Processing Record 215 | alta floresta
# Processing Record 216 | zhuhai
# Processing Record 217 | uglich
# Processing Record 218 | twentynine palms
# Processing Record 219 | tidore
# City not found. Skipping...
# Processing Record 220 | makakilo city
# Processing Record 221 | portsmouth
# Processing Record 222 | soverato
# Processing Record 223 | airai
# Processing Record 224 | tubruq
# City not found. Skipping...
# Processing Record 225 | tahe
# Processing Record 226 | libertador general san martin
# Processing Record 227 | nalut
# Processing Record 228 | thompson
# Processing Record 229 | ostrovnoy
# Processing Record 230 | tateyama
# Processing Record 231 | provideniya
# Processing Record 232 | lavrentiya
# Processing Record 233 | haibowan
# City not found. Skipping...
# Processing Record 234 | lagoa vermelha
# Processing Record 235 | rach gia
# Processing Record 236 | huarmey
# Processing Record 237 | maxixe
# Processing Record 238 | sorvag
# City not found. Skipping...
# Processing Record 239 | coihaique
# Processing Record 240 | labuhan
# Processing Record 241 | yamada
# Processing Record 242 | hofn
# Processing Record 243 | kuche
# City not found. Skipping...
# Processing Record 244 | attawapiskat
# City not found. Skipping...
# Processing Record 245 | fortuna
# Processing Record 246 | nakasongola
# Processing Record 247 | fukue
# Processing Record 248 | natal
# Processing Record 249 | marystown
# Processing Record 250 | komsomolskiy
# Processing Record 251 | ancud
# Processing Record 252 | otradnoye
# Processing Record 253 | mount gambier
# Processing Record 254 | ausa
# Processing Record 255 | daru
# Processing Record 256 | yar-sale
# Processing Record 257 | saldanha
# Processing Record 258 | oranjemund
# Processing Record 259 | tabuk
# Processing Record 260 | kavaratti
# Processing Record 261 | cockburn town
# Processing Record 262 | clyde river
# Processing Record 263 | chernyshevskiy
# Processing Record 264 | sande
# Processing Record 265 | georgetown
# Processing Record 266 | darnah
# Processing Record 267 | srandakan
# Processing Record 268 | det udom
# Processing Record 269 | gauribidanur
# Processing Record 270 | chumikan
# Processing Record 271 | ponta delgada
# Processing Record 272 | corrales
# Processing Record 273 | maniitsoq
# Processing Record 274 | yerbogachen
# Processing Record 275 | aktash
# Processing Record 276 | mannarakkat
# Processing Record 277 | samba
# Processing Record 278 | dingle
# Processing Record 279 | teguise
# Processing Record 280 | banff
# Processing Record 281 | buala
# Processing Record 282 | urumqi
# Processing Record 283 | saint george
# Processing Record 284 | marcona
# City not found. Skipping...
# Processing Record 285 | ardistan
# City not found. Skipping...
# Processing Record 286 | the valley
# Processing Record 287 | uvarovo
# Processing Record 288 | miraflores
# Processing Record 289 | lincoln
# Processing Record 290 | muisne
# Processing Record 291 | goias
# Processing Record 292 | geraldton
# Processing Record 293 | marabba
# Processing Record 294 | norman wells
# Processing Record 295 | bilibino
# Processing Record 296 | jalu
# Processing Record 297 | bambous virieux
# Processing Record 298 | rabaul
# Processing Record 299 | boca do acre
# Processing Record 300 | lorengau
# Processing Record 301 | tanakpur
# Processing Record 302 | lazaro cardenas
# Processing Record 303 | komarichi
# Processing Record 304 | khed brahma
# Processing Record 305 | palabuhanratu
# City not found. Skipping...
# Processing Record 306 | aitape
# Processing Record 307 | wanning
# Processing Record 308 | sorland
# Processing Record 309 | shitkino
# Processing Record 310 | sharlyk
# Processing Record 311 | waynesville
# Processing Record 312 | saint-francois
# Processing Record 313 | marienburg
# Processing Record 314 | olafsvik
# Processing Record 315 | nicoya
# Processing Record 316 | antalaha
# Processing Record 317 | port blair
# Processing Record 318 | manama
# Processing Record 319 | ambilobe
# Processing Record 320 | mumford
# Processing Record 321 | madang
# Processing Record 322 | jarjis
# City not found. Skipping...
# Processing Record 323 | quelimane
# Processing Record 324 | namibe
# Processing Record 325 | kampene
# Processing Record 326 | shimoda
# Processing Record 327 | hovd
# Processing Record 328 | kieta
# Processing Record 329 | sladkovo
# Processing Record 330 | mezen
# Processing Record 331 | galiwinku
# City not found. Skipping...
# Processing Record 332 | bukachacha
# Processing Record 333 | bengkulu
# Processing Record 334 | klaksvik
# Processing Record 335 | semey
# Processing Record 336 | sabang
# Processing Record 337 | mana
# Processing Record 338 | cuencame
# Processing Record 339 | vila franca do campo
# Processing Record 340 | kenai
# Processing Record 341 | nandu
# Processing Record 342 | banjar
# Processing Record 343 | pallasovka
# Processing Record 344 | pisco
# Processing Record 345 | kamaishi
# Processing Record 346 | buraydah
# Processing Record 347 | shush
# Processing Record 348 | zhezkazgan
# Processing Record 349 | wukari
# Processing Record 350 | atbasar
# Processing Record 351 | mahenge
# Processing Record 352 | aswan
# Processing Record 353 | guymon
# Processing Record 354 | sinazongwe
# Processing Record 355 | storsteinnes
# Processing Record 356 | grindavik
# Processing Record 357 | conde
# Processing Record 358 | megion
# Processing Record 359 | tsihombe
# City not found. Skipping...
# Processing Record 360 | santa isabel do rio negro
# Processing Record 361 | kamenskoye
# City not found. Skipping...
# Processing Record 362 | omboue
# Processing Record 363 | mata
# Processing Record 364 | homer
# Processing Record 365 | sakakah
# Processing Record 366 | matadi
# Processing Record 367 | presidente medici
# Processing Record 368 | bose
# Processing Record 369 | matara
# Processing Record 370 | sao miguel do araguaia
# Processing Record 371 | muros
# Processing Record 372 | gat
# Processing Record 373 | grand gaube
# Processing Record 374 | kollumerland
# City not found. Skipping...
# Processing Record 375 | khani
# Processing Record 376 | shiyan
# Processing Record 377 | cairns
# Processing Record 378 | miri
# Processing Record 379 | srednekolymsk
# Processing Record 380 | emba
# Processing Record 381 | lucapa
# Processing Record 382 | tezu
# Processing Record 383 | vestmannaeyjar
# Processing Record 384 | vrangel
# Processing Record 385 | bonga
# Processing Record 386 | half moon bay
# Processing Record 387 | saint anthony
# Processing Record 388 | nome
# Processing Record 389 | turayf
# Processing Record 390 | betioky
# Processing Record 391 | burns lake
# Processing Record 392 | vila velha
# Processing Record 393 | talmenka
# Processing Record 394 | jaora
# Processing Record 395 | sorrento
# Processing Record 396 | elwood
# Processing Record 397 | pizarro
# Processing Record 398 | aulla
# Processing Record 399 | ambovombe
# Processing Record 400 | menongue
# Processing Record 401 | sur
# Processing Record 402 | puerto lempira
# Processing Record 403 | paamiut
# Processing Record 404 | alofi
# Processing Record 405 | camacha
# Processing Record 406 | harihar
# Processing Record 407 | moerai
# Processing Record 408 | nanortalik
# Processing Record 409 | mission
# Processing Record 410 | viisoara
# Processing Record 411 | saint marys
# Processing Record 412 | bilma
# Processing Record 413 | floresta
# Processing Record 414 | milos
# Processing Record 415 | sikonge
# Processing Record 416 | gurgan
# City not found. Skipping...
# Processing Record 417 | safaga
# Processing Record 418 | wuda
# Processing Record 419 | bubaque
# Processing Record 420 | myski
# Processing Record 421 | bermeo
# Processing Record 422 | nagorsk
# Processing Record 423 | banda aceh
# Processing Record 424 | morgan city
# Processing Record 425 | himatnagar
# Processing Record 426 | swift current
# Processing Record 427 | gazojak
# Processing Record 428 | skjervoy
# Processing Record 429 | matay
# Processing Record 430 | norheimsund
# Processing Record 431 | north bay
# Processing Record 432 | ballina
# Processing Record 433 | walvis bay
# Processing Record 434 | mitsamiouli
# Processing Record 435 | guilin
# Processing Record 436 | amahai
# Processing Record 437 | soure
# Processing Record 438 | inirida
# Processing Record 439 | haines junction
# Processing Record 440 | arroio grande
# Processing Record 441 | havre-saint-pierre
# Processing Record 442 | irbeyskoye
# Processing Record 443 | dehloran
# Processing Record 444 | nyazepetrovsk
# Processing Record 445 | naze
# Processing Record 446 | goure
# Processing Record 447 | pauini
# Processing Record 448 | tual
# Processing Record 449 | fuerte olimpo
# Processing Record 450 | bolpur
# Processing Record 451 | avera
# Processing Record 452 | kavieng
# Processing Record 453 | bethlehem
# Processing Record 454 | la palma
# Processing Record 455 | toora-khem
# Processing Record 456 | nambucca heads
# Processing Record 457 | beihai
# Processing Record 458 | ossora
# Processing Record 459 | ixtapa
# Processing Record 460 | ketchikan
# Processing Record 461 | matamoros
# Processing Record 462 | ngukurr
# City not found. Skipping...
# Processing Record 463 | rungata
# City not found. Skipping...
# Processing Record 464 | nishihara
# Processing Record 465 | muyezerskiy
# Processing Record 466 | palmas
# Processing Record 467 | pahrump
# Processing Record 468 | mount isa
# Processing Record 469 | la romana
# Processing Record 470 | tarudant
# City not found. Skipping...
# Processing Record 471 | marzuq
# Processing Record 472 | chicama
# Processing Record 473 | maromitsa
# Processing Record 474 | zhangjiakou
# Processing Record 475 | pochutla
# Processing Record 476 | louis trichardt
# Processing Record 477 | olavarria
# Processing Record 478 | osmanabad
# Processing Record 479 | krasnovishersk
# Processing Record 480 | tilichiki
# Processing Record 481 | marfino
# Processing Record 482 | barroualie
# City not found. Skipping...
# Processing Record 483 | mishan
# Processing Record 484 | bambanglipuro
# Processing Record 485 | high prairie
# Processing Record 486 | longavi
# Processing Record 487 | sakaiminato
# Processing Record 488 | tautira
# Processing Record 489 | brezova pod bradlom
# Processing Record 490 | farmington
# Processing Record 491 | aranos
# Processing Record 492 | candido mendes
# Processing Record 493 | qasigiannguit
# Processing Record 494 | egvekinot
# Processing Record 495 | anori
# Processing Record 496 | yantal
# Processing Record 497 | mafinga
# Processing Record 498 | rawlins
# Processing Record 499 | port hedland
# Processing Record 500 | bargal
# City not found. Skipping...
# Processing Record 501 | dalbandin
# Processing Record 502 | ampanihy
# Processing Record 503 | henties bay
# Processing Record 504 | padang
# Processing Record 505 | yichang
# Processing Record 506 | kalispell
# Processing Record 507 | pilar
# Processing Record 508 | hami
# Processing Record 509 | hamilton
# Processing Record 510 | nioro
# Processing Record 511 | sitka
# Processing Record 512 | shache
# Processing Record 513 | saquarema
# Processing Record 514 | manzhouli
# Processing Record 515 | cayenne
# Processing Record 516 | virginia beach
# Processing Record 517 | maldonado
# Processing Record 518 | luderitz
# Processing Record 519 | zhoucun
# Processing Record 520 | mogadishu
# Processing Record 521 | caravelas
# Processing Record 522 | aasiaat
# Processing Record 523 | denpasar
# Processing Record 524 | porosozero
# Processing Record 525 | quatre cocos
# Processing Record 526 | te anau
# Processing Record 527 | alice springs
# Processing Record 528 | kamyshla
# Processing Record 529 | faya
# Processing Record 530 | chama
# Processing Record 531 | san borja
# Processing Record 532 | namatanai
# Processing Record 533 | humaita
# Processing Record 534 | saumur
# Processing Record 535 | yongan
# Processing Record 536 | mlonggo
# Processing Record 537 | bairiki
# Processing Record 538 | lasa
# Processing Record 539 | thinadhoo
# Processing Record 540 | kysyl-syr
# Processing Record 541 | jingdezhen
# Processing Record 542 | pangnirtung
# Processing Record 543 | turbat
# Processing Record 544 | soyo
# Processing Record 545 | mandalgovi
# Processing Record 546 | noumea
# Processing Record 547 | louisbourg
# City not found. Skipping...
# Processing Record 548 | xining
# Processing Record 549 | taoudenni
# Processing Record 550 | lubao
# Processing Record 551 | leh
# Processing Record 552 | dawei
# Processing Record 553 | kalmunai
# Processing Record 554 | bodaybo
# Processing Record 555 | tonantins
# Processing Record 556 | pacific grove
# Processing Record 557 | waingapu
# Processing Record 558 | saryshagan
# City not found. Skipping...
# Processing Record 559 | zhigansk
# Processing Record 560 | forssa
# Processing Record 561 | tumannyy
# City not found. Skipping...
# Processing Record 562 | chapais
# Processing Record 563 | vao
# Processing Record 564 | praya
# Processing Record 565 | bhadrachalam
# Processing Record 566 | honningsvag
# Processing Record 567 | terrace
# Processing Record 568 | palmer
# Processing Record 569 | port arthur
# Processing Record 570 | general roca
# Processing Record 571 | roswell
# Processing Record 572 | bathsheba
# Processing Record 573 | coquimbo
# Processing Record 574 | ordzhonikidze
# Processing Record 575 | timra
# Processing Record 576 | hobyo
# Processing Record 577 | mbanza-ngungu
# Processing Record 578 | llanes
# Processing Record 579 | gwadar
# Processing Record 580 | byron bay
# Processing Record 581 | yanan
# City not found. Skipping...
# Processing Record 582 | russell
# Processing Record 583 | port macquarie
# Processing Record 584 | shingu
# Processing Record 585 | hadsten
# Processing Record 586 | talara
# Processing Record 587 | santa cruz
# Processing Record 588 | lieksa
# Processing Record 589 | hazorasp
# Processing Record 590 | eyl
# Processing Record 591 | pemba
# Processing Record 592 | raudeberg
# Processing Record 593 | souillac
# Processing Record 594 | hvolsvollur
# Processing Record 595 | mandera
# Processing Record 596 | lundazi
# Processing Record 597 | celestun
# Processing Record 598 | kolda
# Processing Record 599 | golfito
# Processing Record 600 | ust-nera
# Processing Record 601 | ozernovskiy
# Processing Record 602 | corbelia
# Processing Record 603 | kaitangata
# Processing Record 604 | luena
# Processing Record 605 | nortelandia
# Processing Record 606 | oberwil
# Processing Record 607 | necochea
# Processing Record 608 | sinnamary
# Processing Record 609 | goderich
# Processing Record 610 | rehnan
# Processing Record 611 | evensk
# Processing Record 612 | afgoye
# City not found. Skipping...
# Processing Record 613 | jiwani
# Processing Record 614 | germersheim
# Processing Record 615 | ust-barguzin
# Processing Record 616 | vardo
# Processing Record 617 | salvador
# Processing Record 618 | isangel
# Processing Record 619 | iquique
# Processing Record 620 | mount darwin
# Processing Record 621 | verkhnyaya inta
# Processing Record 622 | ler
# Processing Record 623 | upington

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df = pd.DataFrame({"City" : city_name, "Cloudiness" : cloudiness, "Country" : country, "Date" : date,
                           "Humidity" : humidity, "Lat" : lat, "Lng" : lng, "Max Temp" : max_temp,
                           "Wind Speed" : wind_speed})
weather_df.to_csv(path_or_buf=output_data_file,index=False,encoding="UTF-8")
weather_df.head()
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  Cabo San Lucas           5      MX  1583117643        56  22.89 -109.91
# 1        Hermanus           0      ZA  1583117707        90 -34.42   19.23
# 2          Japura           4      ID  1583117707        60  -0.32  102.35
# 3          Narsaq           0      GL  1583117707        49  60.92  -46.05
# 4            Fare         100      PF  1583117707        76 -16.70 -151.02
#
#    Max Temp  Wind Speed
# 0    295.15        6.70
# 1    292.59        6.55
# 2    303.89        1.61
# 3    256.15        1.00
# 4    301.39        9.91

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df["Max Temp"], weather_df["Lat"], facecolors = "lightskyblue", edgecolor="black",
            alpha = 0.7, linewidth = 1)
plt.grid()
plt.title("City Latitude vs. Max Temperature (02/29/2020)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (°F)")
plt.savefig("./Images/latvstemp.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Humidity"], facecolors = "lightskyblue", edgecolor="black",
            alpha = 0.7, linewidth = 1)
plt.grid()
plt.title("City Latitude vs. Humidity (02/29/2020)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.savefig("./Images/latvshumidity.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], facecolors = "lightskyblue", edgecolor="black",
            alpha = 0.7, linewidth = 1)
plt.grid()
plt.title("City Latitude vs. Cloudiness (02/29/2020)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.savefig("./Images/latvscloudiness.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], facecolors = "lightskyblue", edgecolor="black",
            alpha = 0.7, linewidth = 1)
plt.grid()
plt.title("City Latitude vs. Wind Speed (02/29/2020)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.savefig("./Images/latvswindspeed.png")
plt.show()
